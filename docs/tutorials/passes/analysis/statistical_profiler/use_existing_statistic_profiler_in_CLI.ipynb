# %% [markdown]
# # Use Existing Statistical Profiler in CLI
# "profile_statistics" is available as an analysis pass in Machop CLI. Here we show how to use it to profile the statistics the weight and activations of a resnet18 pretrained on ImageNet.

# %% [markdown]
# ## Example: the range of weights & input activations of a `Conv2d` node
#
# Say we want to collect the tensor-wise min-max range of the 1st `torch.nn.Conv2d` nodes' weights & bias, and the channel-wise 97% quantile min-max of the 1st `torch.nn.Conv2d` nodes' input activations. We can do the following:
#
# > **Note**
# > - Tensor-wise min-max of weights: `Conv2d` has a weight tensor of shape `(out_channels, in_channels, kernel_size, kernel_size)`, so we need to reduce all dimensions of the weight tensor.
# > - Channel-wise 97% quantile min-max of activations: `Conv2d` has an activation tensor of shape `(batch_size, in_channels, height, width)`, so we need to reduce the `0`-th, `2`-nd, and `3`-rd dimensions of the activation tensor. 97% quantile min-max means we sort the input activation tensors ascendingly, and take the min at 3% of the sorted tensor, and the max at 97% of the sorted tensor.

# %% [markdown]
# ### Create a config toml for Machop CLI

# %%
import toml

config = {
    "model": "resnet18",
    "dataset": "cifar10",  # we use cifar10 as an example since imagenet is too large
    "batch_size": 4,
    "pretrained": True,
    "passes": {
        "profile_statistics": {
            "by": "name",  # collect statistics by node name
            "target_weight_nodes": [
                "conv1"
            ],  # the 1st conv2d node name is "conv1". collect the statistics of the weight tensor
            "target_activation_nodes": [
                "conv1"
            ],  # collects the statistics of the 1st conv2d node
            "weight_statistics": {
                # collect the min-max range of the weight tensor
                "range_min_max": {
                    "dims": "all",  # reduce all dimensions
                    "abs": False,  # do not take the absolute value before min max reduction
                }
            },
            "activation_statistics": {
                "range_quantile": {
                    "dims": [
                        0,
                        2,
                        3,
                    ],  # reduced dim = 0, 2, 3. The min-max is a 1D tensor of shape (C_in,)
                    "abs": False,
                    "quantile": 0.97,  # take the 97% quantile
                }
            },
            "num_samples": 32,  # feed 32 samples to the model
        },
        "report_node_meta_param": {"which": ["software"]},
        "save_node_meta_param": {"save_path": "node_software_meta_param_cli.toml"},
    },
}

# Save the config to a toml file
with open("config.toml", "w") as f:
    toml.dump(config, f)

# %% [markdown]
# Here is how the CLI config toml looks like:
#
# the entry `passes.profile_statistics` specifies the profiler behavior.

# %%
! cat config.toml
# Out:
# model = "resnet18"
# dataset = "cifar10"
# batch_size = 4
# pretrained = true
#
# [passes.profile_statistics]
# by = "name"
# target_weight_nodes = [ "conv1",]
# target_activation_nodes = [ "conv1",]
# num_samples = 32
#
# [passes.report_node_meta_param]
# which = [ "software",]
#
# [passes.save_node_meta_param]
# save_path = "node_software_meta_param_cli.toml"
#
# [passes.profile_statistics.weight_statistics.range_min_max]
# dims = "all"
# abs = false
#
# [passes.profile_statistics.activation_statistics.range_quantile]
# dims = [ 0, 2, 3,]
# abs = false
# quantile = 0.97

# %% [markdown]
# ### Run CLI

# %%
! ../../../../../machop/ch transform --config ./config.toml
# Out:
# /home/zz7522/anaconda3/envs/mase-sw/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Global seed set to 0
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | Name                    |         Default          | Config. File | Manual Override |        Effective         |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | task                    |      classification      |              |                 |      classification      |
# | load_name               |           None           |              |                 |           None           |
# | load_type               |            mz            |              |                 |            mz            |
# | batch_size              |           128            |      4       |                 |            4             |
# | to_debug                |          False           |              |                 |          False           |
# | log_level               |           info           |              |                 |           info           |
# | seed                    |            0             |              |                 |            0             |
# | training_optimizer      |           adam           |              |                 |           adam           |
# | trainer_precision       |            32            |              |                 |            32            |
# | learning_rate           |          1e-05           |              |                 |          1e-05           |
# | max_epochs              |            20            |              |                 |            20            |
# | max_steps               |            -1            |              |                 |            -1            |
# | accumulate_grad_batches |            1             |              |                 |            1             |
# | num_workers             |            32            |              |                 |            32            |
# | num_devices             |            1             |              |                 |            1             |
# | num_nodes               |            1             |              |                 |            1             |
# | accelerator             |           auto           |              |                 |           auto           |
# | strategy                |           ddp            |              |                 |           ddp            |
# | is_to_auto_requeue      |          False           |              |                 |          False           |
# | github_ci               |          False           |              |                 |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                 |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                 |           100            |
# | is_pretrained           |          False           |              |                 |          False           |
# | max_token_len           |           512            |              |                 |           512            |
# | project_dir             | /data/zz7522/Projects/ma |              |                 | /data/zz7522/Projects/ma |
# |                         |   se-tools/mase_output   |              |                 |   se-tools/mase_output   |
# | project                 |           None           |              |                 |           None           |
# | model                   |           None           |   resnet18   |                 |         resnet18         |
# | dataset                 |           None           |   cifar10    |                 |         cifar10          |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# [2023-07-27 20:30:18][chop][INFO] Initialising model 'resnet18'...
# [2023-07-27 20:30:18][chop][INFO] Initialising dataset 'cifar10'...
# [2023-07-27 20:30:18][chop][INFO] Project will be created at /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27
# [2023-07-27 20:30:18][chop][INFO] Transforming model 'resnet18'...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Profiling weight statistics: 100%|████████████| 71/71 [00:00<00:00, 6754.73it/s]
# Profiling act statistics: 100%|███████████████████| 8/8 [00:00<00:00, 24.90it/s]
# [2023-07-27 20:30:26][chop.passes.analysis.report.report_node][INFO] Inspecting graph [add_common_meta_param_analysis_pass]
# [2023-07-27 20:30:26][chop.passes.analysis.report.report_node][INFO]
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | Node name             | Fx Node op    | Mase type           | Mase op             | Software Param                                                                       |
# +=======================+===============+=====================+=====================+======================================================================================+
# | x                     | placeholder   | placeholder         | placeholder         | {'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | conv1                 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_quantile': {'count': 32768,                  |
# |                       |               |                     |                     |                                                     'max': [2.0605359077453613,      |
# |                       |               |                     |                     |                                                             2.21848726272583,        |
# |                       |               |                     |                     |                                                             2.5877127647399902],     |
# |                       |               |                     |                     |                                                     'min': [-2.1179039478302,        |
# |                       |               |                     |                     |                                                             -2.0357141494750977,     |
# |                       |               |                     |                     |                                                             -1.804444432258606],     |
# |                       |               |                     |                     |                                                     'range': [4.178440093994141,     |
# |                       |               |                     |                     |                                                               4.254201412200928,     |
# |                       |               |                     |                     |                                                               4.392157077789307]}}}, |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 9408,                       |
# |                       |               |                     |                     |                                                 'max': 0.0992252454161644,           |
# |                       |               |                     |                     |                                                 'min': -0.1031746193766594,          |
# |                       |               |                     |                     |                                                 'range': 0.2023998647928238}}}},     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | bn1                   | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | relu                  | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | maxpool               | call_module   | module_related_func | max_pool2d          | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add                   | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_1                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_2                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_3                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_4                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_5                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_6                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_7                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | avgpool               | call_module   | module_related_func | adaptive_avg_pool2d | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | flatten               | call_function | implicit_func       | flatten             | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | fc                    | call_module   | module_related_func | linear              | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | output                | output        | output              | output              | {'args': {'data_in_0': {'stat': {}}}}                                                |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# [2023-07-27 20:30:26][chop.passes.analysis.report.report_node][INFO] Node meta param table is saved to /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27/software/transformed_ckpts/report
# [2023-07-27 20:30:26][chop.passes.transforms.interface.save_and_load][INFO] Saved mase graph to /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27/software/transformed_ckpts
# [2023-07-27 20:30:26][chop][INFO] Transformation is completed

# %% [markdown]
# ## A More Complex Example
#
# Here is an example of collecting various statistics of a ResNet18 model by node type.

# %%
import toml

config = {
    "model": "resnet18",
    "dataset": "cifar10",  # we use cifar10 as an example since imagenet is too large
    "batch_size": 4,
    "pretrained": True,
    "passes": {
        "profile_statistics": {
            "by": "type",
            "target_weight_nodes": [
                "linear",
                "conv2d",
                "batch_norm2d",
                "adaptive_avg_pool2d",
                "relu",
            ],
            "target_activation_nodes": [
                "linear",
                "conv2d",
                "batch_norm2d",
                "adaptive_avg_pool2d",
                "relu",
            ],
            "weight_statistics": {
                # "record": {"device": "cuda"},
                "variance_online": {"device": "cuda", "dims": "all"},
                "variance_precise": {"device": "cuda", "dims": "all"},
                "range_n_sigma": {
                    "device": "cuda",
                    "dims": "all",
                    "abs": False,
                    "var_mode": "precise",
                    "num_sigma": 3,
                },
                "range_min_max": {"device": "cuda", "dims": "all", "abs": False},
                "range_quantile": {
                    "device": "cuda",
                    "dims": "all",
                    "abs": False,
                    "quantile": 0.97,
                },
            },
            "activation_statistics": {
                # "record": {"device": "cuda"},
                "variance_online": {"device": "cuda", "dims": "all"},
                "variance_precise": {"device": "cuda", "dims": "all"},
                "range_n_sigma": {
                    "device": "cuda",
                    "dims": "all",
                    "abs": False,
                    "var_mode": "precise",
                    "num_sigma": 3,
                },
                "range_min_max": {"device": "cuda", "dims": "all", "abs": False},
                "range_quantile": {
                    "device": "cuda",
                    "dims": "all",
                    "abs": False,
                    "quantile": 0.97,
                },
            },
            "num_samples": 32,
        },
        "report_node_meta_param": {"which": ["software"]},
        "save_node_meta_param": {"save_path": "node_software_meta_param_cli_complex.toml"},
    },
}

# Save the config to a toml file
with open("config_complex.toml", "w") as f:
    toml.dump(config, f)

# %%
! ../../../../../machop/ch transform --config ./config_complex.toml
# Out:
# /home/zz7522/anaconda3/envs/mase-sw/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Global seed set to 0
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | Name                    |         Default          | Config. File | Manual Override |        Effective         |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# | task                    |      classification      |              |                 |      classification      |
# | load_name               |           None           |              |                 |           None           |
# | load_type               |            mz            |              |                 |            mz            |
# | batch_size              |           128            |      4       |                 |            4             |
# | to_debug                |          False           |              |                 |          False           |
# | log_level               |           info           |              |                 |           info           |
# | seed                    |            0             |              |                 |            0             |
# | training_optimizer      |           adam           |              |                 |           adam           |
# | trainer_precision       |            32            |              |                 |            32            |
# | learning_rate           |          1e-05           |              |                 |          1e-05           |
# | max_epochs              |            20            |              |                 |            20            |
# | max_steps               |            -1            |              |                 |            -1            |
# | accumulate_grad_batches |            1             |              |                 |            1             |
# | num_workers             |            32            |              |                 |            32            |
# | num_devices             |            1             |              |                 |            1             |
# | num_nodes               |            1             |              |                 |            1             |
# | accelerator             |           auto           |              |                 |           auto           |
# | strategy                |           ddp            |              |                 |           ddp            |
# | is_to_auto_requeue      |          False           |              |                 |          False           |
# | github_ci               |          False           |              |                 |          False           |
# | target                  |   xcu250-figd2104-2L-e   |              |                 |   xcu250-figd2104-2L-e   |
# | num_targets             |           100            |              |                 |           100            |
# | is_pretrained           |          False           |              |                 |          False           |
# | max_token_len           |           512            |              |                 |           512            |
# | project_dir             | /data/zz7522/Projects/ma |              |                 | /data/zz7522/Projects/ma |
# |                         |   se-tools/mase_output   |              |                 |   se-tools/mase_output   |
# | project                 |           None           |              |                 |           None           |
# | model                   |           None           |   resnet18   |                 |         resnet18         |
# | dataset                 |           None           |   cifar10    |                 |         cifar10          |
# +-------------------------+--------------------------+--------------+-----------------+--------------------------+
# [2023-07-27 22:14:29][chop][INFO] Initialising model 'resnet18'...
# [2023-07-27 22:14:29][chop][INFO] Initialising dataset 'cifar10'...
# [2023-07-27 22:14:29][chop][INFO] Project will be created at /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27
# [2023-07-27 22:14:29][chop][INFO] Transforming model 'resnet18'...
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Profiling weight statistics: 100%|██████████████| 71/71 [00:01<00:00, 42.53it/s]
# Profiling act statistics: 100%|███████████████████| 8/8 [00:01<00:00,  4.37it/s]
# [2023-07-27 22:14:40][chop.passes.analysis.report.report_node][INFO] Inspecting graph [add_common_meta_param_analysis_pass]
# [2023-07-27 22:14:40][chop.passes.analysis.report.report_node][INFO]
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | Node name             | Fx Node op    | Mase type           | Mase op             | Software Param                                                                             |
# +=======================+===============+=====================+=====================+============================================================================================+
# | x                     | placeholder   | placeholder         | placeholder         | {'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | conv1                 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 98304,                         |
# |                       |               |                     |                     |                                                    'max': 4.135890007019043,               |
# |                       |               |                     |                     |                                                    'min': -3.855949878692627,              |
# |                       |               |                     |                     |                                                    'range': 7.99183988571167},             |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 98304,                         |
# |                       |               |                     |                     |                                                    'max': 3.6434993743896484,              |
# |                       |               |                     |                     |                                                    'min': -3.853762626647949,              |
# |                       |               |                     |                     |                                                    'range': 7.497262001037598},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 98304,                        |
# |                       |               |                     |                     |                                                     'max': 2.3235294818878174,             |
# |                       |               |                     |                     |                                                     'min': -2.1179039478302,               |
# |                       |               |                     |                     |                                                     'range': 4.441433429718018},           |
# |                       |               |                     |                     |                                  'variance_online': {'count': 98304,                       |
# |                       |               |                     |                     |                                                      'mean': -0.10513171553611755,         |
# |                       |               |                     |                     |                                                      'variance': 1.5617464780807495},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 98304,                      |
# |                       |               |                     |                     |                                                       'mean': -0.10513171553611755,        |
# |                       |               |                     |                     |                                                       'variance': 1.5613592863082886}}},   |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 9408,                             |
# |                       |               |                     |                     |                                                 'max': 0.0992252454161644,                 |
# |                       |               |                     |                     |                                                 'min': -0.1031746193766594,                |
# |                       |               |                     |                     |                                                 'range': 0.2023998647928238},              |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 9408,                             |
# |                       |               |                     |                     |                                                 'max': 0.07599679380655289,                |
# |                       |               |                     |                     |                                                 'min': -0.07614002376794815,               |
# |                       |               |                     |                     |                                                 'range': 0.15213681757450104},             |
# |                       |               |                     |                     |                               'range_quantile': {'count': 9408,                            |
# |                       |               |                     |                     |                                                  'max': 0.04751560091972351,               |
# |                       |               |                     |                     |                                                  'min': -0.04771643131971359,              |
# |                       |               |                     |                     |                                                  'range': 0.0952320322394371},             |
# |                       |               |                     |                     |                               'variance_online': {'count': 9408,                           |
# |                       |               |                     |                     |                                                   'mean': -7.161527901189402e-05,          |
# |                       |               |                     |                     |                                                   'variance': 0.0006429337081499398},      |
# |                       |               |                     |                     |                               'variance_precise': {'count': 9408,                          |
# |                       |               |                     |                     |                                                    'mean': -7.161527901189402e-05,         |
# |                       |               |                     |                     |                                                    'variance': 0.0006429337081499398}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | bn1                   | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {'range_min_max': {'count': 64,                                 |
# |                       |               |                     |                     |                                               'max': 0.0,                                  |
# |                       |               |                     |                     |                                               'min': 0.0,                                  |
# |                       |               |                     |                     |                                               'range': 0.0},                               |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 64,                                 |
# |                       |               |                     |                     |                                               'max': 0.0,                                  |
# |                       |               |                     |                     |                                               'min': 0.0,                                  |
# |                       |               |                     |                     |                                               'range': 0.0},                               |
# |                       |               |                     |                     |                             'range_quantile': {'count': 64,                                |
# |                       |               |                     |                     |                                                'max': 0.0,                                 |
# |                       |               |                     |                     |                                                'min': 0.0,                                 |
# |                       |               |                     |                     |                                                'range': 0.0},                              |
# |                       |               |                     |                     |                             'variance_online': {'count': 64,                               |
# |                       |               |                     |                     |                                                 'mean': 0.0,                               |
# |                       |               |                     |                     |                                                 'variance': 0.0},                          |
# |                       |               |                     |                     |                             'variance_precise': {'count': 64,                              |
# |                       |               |                     |                     |                                                  'mean': 0.0,                              |
# |                       |               |                     |                     |                                                  'variance': 0.0}}},                       |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 524288,                        |
# |                       |               |                     |                     |                                                    'max': 1.892829418182373,               |
# |                       |               |                     |                     |                                                    'min': -2.0799500942230225,             |
# |                       |               |                     |                     |                                                    'range': 3.9727795124053955},           |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 524288,                        |
# |                       |               |                     |                     |                                                    'max': 0.9973894953727722,              |
# |                       |               |                     |                     |                                                    'min': -0.9985914826393127,             |
# |                       |               |                     |                     |                                                    'range': 1.995980978012085},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 524288,                       |
# |                       |               |                     |                     |                                                     'max': 0.6565704941749573,             |
# |                       |               |                     |                     |                                                     'min': -0.6685211062431335,            |
# |                       |               |                     |                     |                                                     'range': 1.3250916004180908},          |
# |                       |               |                     |                     |                                  'variance_online': {'count': 524288,                      |
# |                       |               |                     |                     |                                                      'mean': -0.0006010221550241113,       |
# |                       |               |                     |                     |                                                      'variance': 0.11067154258489609},     |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 524288,                     |
# |                       |               |                     |                     |                                                       'mean': -0.0006010229699313641,      |
# |                       |               |                     |                     |                                                       'variance': 0.11066500097513199}}},  |
# |                       |               |                     |                     |           'running_mean': {'stat': {'range_min_max': {'count': 64,                         |
# |                       |               |                     |                     |                                                       'max': 0.0,                          |
# |                       |               |                     |                     |                                                       'min': 0.0,                          |
# |                       |               |                     |                     |                                                       'range': 0.0},                       |
# |                       |               |                     |                     |                                     'range_n_sigma': {'count': 64,                         |
# |                       |               |                     |                     |                                                       'max': 0.0,                          |
# |                       |               |                     |                     |                                                       'min': 0.0,                          |
# |                       |               |                     |                     |                                                       'range': 0.0},                       |
# |                       |               |                     |                     |                                     'range_quantile': {'count': 64,                        |
# |                       |               |                     |                     |                                                        'max': 0.0,                         |
# |                       |               |                     |                     |                                                        'min': 0.0,                         |
# |                       |               |                     |                     |                                                        'range': 0.0},                      |
# |                       |               |                     |                     |                                     'variance_online': {'count': 64,                       |
# |                       |               |                     |                     |                                                         'mean': 0.0,                       |
# |                       |               |                     |                     |                                                         'variance': 0.0},                  |
# |                       |               |                     |                     |                                     'variance_precise': {'count': 64,                      |
# |                       |               |                     |                     |                                                          'mean': 0.0,                      |
# |                       |               |                     |                     |                                                          'variance': 0.0}}},               |
# |                       |               |                     |                     |           'running_var': {'stat': {'range_min_max': {'count': 64,                          |
# |                       |               |                     |                     |                                                      'max': 1.0,                           |
# |                       |               |                     |                     |                                                      'min': 1.0,                           |
# |                       |               |                     |                     |                                                      'range': 0.0},                        |
# |                       |               |                     |                     |                                    'range_n_sigma': {'count': 64,                          |
# |                       |               |                     |                     |                                                      'max': 1.0,                           |
# |                       |               |                     |                     |                                                      'min': 1.0,                           |
# |                       |               |                     |                     |                                                      'range': 0.0},                        |
# |                       |               |                     |                     |                                    'range_quantile': {'count': 64,                         |
# |                       |               |                     |                     |                                                       'max': 1.0,                          |
# |                       |               |                     |                     |                                                       'min': 1.0,                          |
# |                       |               |                     |                     |                                                       'range': 0.0},                       |
# |                       |               |                     |                     |                                    'variance_online': {'count': 64,                        |
# |                       |               |                     |                     |                                                        'mean': 1.0,                        |
# |                       |               |                     |                     |                                                        'variance': 0.0},                   |
# |                       |               |                     |                     |                                    'variance_precise': {'count': 64,                       |
# |                       |               |                     |                     |                                                         'mean': 1.0,                       |
# |                       |               |                     |                     |                                                         'variance': 0.0}}},                |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 64,                               |
# |                       |               |                     |                     |                                                 'max': 1.0,                                |
# |                       |               |                     |                     |                                                 'min': 1.0,                                |
# |                       |               |                     |                     |                                                 'range': 0.0},                             |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 64,                               |
# |                       |               |                     |                     |                                                 'max': 1.0,                                |
# |                       |               |                     |                     |                                                 'min': 1.0,                                |
# |                       |               |                     |                     |                                                 'range': 0.0},                             |
# |                       |               |                     |                     |                               'range_quantile': {'count': 64,                              |
# |                       |               |                     |                     |                                                  'max': 1.0,                               |
# |                       |               |                     |                     |                                                  'min': 1.0,                               |
# |                       |               |                     |                     |                                                  'range': 0.0},                            |
# |                       |               |                     |                     |                               'variance_online': {'count': 64,                             |
# |                       |               |                     |                     |                                                   'mean': 1.0,                             |
# |                       |               |                     |                     |                                                   'variance': 0.0},                        |
# |                       |               |                     |                     |                               'variance_precise': {'count': 64,                            |
# |                       |               |                     |                     |                                                    'mean': 1.0,                            |
# |                       |               |                     |                     |                                                    'variance': 0.0}}}},                    |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | relu                  | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 524288,                        |
# |                       |               |                     |                     |                                                    'max': 5.621131420135498,               |
# |                       |               |                     |                     |                                                    'min': -5.336169719696045,              |
# |                       |               |                     |                     |                                                    'range': 10.957301139831543},           |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 524288,                        |
# |                       |               |                     |                     |                                                    'max': 2.999807119369507,               |
# |                       |               |                     |                     |                                                    'min': -2.999807119369507,              |
# |                       |               |                     |                     |                                                    'range': 5.999614238739014},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 524288,                       |
# |                       |               |                     |                     |                                                     'max': 1.9265477657318115,             |
# |                       |               |                     |                     |                                                     'min': -1.952881097793579,             |
# |                       |               |                     |                     |                                                     'range': 3.8794288635253906},          |
# |                       |               |                     |                     |                                  'variance_online': {'count': 524288,                      |
# |                       |               |                     |                     |                                                      'mean': 6.111804395914078e-10,        |
# |                       |               |                     |                     |                                                      'variance': 0.9999305605888367},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 524288,                     |
# |                       |               |                     |                     |                                                       'mean': -2.3283064365386963e-10,     |
# |                       |               |                     |                     |                                                       'variance': 0.9998714327812195}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | maxpool               | call_module   | module_related_func | max_pool2d          | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}             |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | layer1_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 131072,                        |
# |                       |               |                     |                     |                                                    'max': 5.621131420135498,               |
# |                       |               |                     |                     |                                                    'min': 0.0,                             |
# |                       |               |                     |                     |                                                    'range': 5.621131420135498},            |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 131072,                        |
# |                       |               |                     |                     |                                                    'max': 3.460095167160034,               |
# |                       |               |                     |                     |                                                    'min': -1.551452398300171,              |
# |                       |               |                     |                     |                                                    'range': 5.011547565460205},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 131072,                       |
# |                       |               |                     |                     |                                                     'max': 2.776937246322632,              |
# |                       |               |                     |                     |                                                     'min': 0.0,                            |
# |                       |               |                     |                     |                                                     'range': 2.776937246322632},           |
# |                       |               |                     |                     |                                  'variance_online': {'count': 131072,                      |
# |                       |               |                     |                     |                                                      'mean': 0.9543214440345764,           |
# |                       |               |                     |                     |                                                      'variance': 0.6977943181991577},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 131072,                     |
# |                       |               |                     |                     |                                                       'mean': 0.9543213248252869,          |
# |                       |               |                     |                     |                                                       'variance': 0.6976558566093445}}},   |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 36864,                            |
# |                       |               |                     |                     |                                                 'max': 0.26726120710372925,                |
# |                       |               |                     |                     |                                                 'min': -0.24428901076316833,               |
# |                       |               |                     |                     |                                                 'range': 0.5115501880645752},              |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 36864,                            |
# |                       |               |                     |                     |                                                 'max': 0.17769497632980347,                |
# |                       |               |                     |                     |                                                 'min': -0.17819786071777344,               |
# |                       |               |                     |                     |                                                 'range': 0.3558928370475769},              |
# |                       |               |                     |                     |                               'range_quantile': {'count': 36864,                           |
# |                       |               |                     |                     |                                                  'max': 0.11087124049663544,               |
# |                       |               |                     |                     |                                                  'min': -0.11168424785137177,              |
# |                       |               |                     |                     |                                                  'range': 0.2225554883480072},             |
# |                       |               |                     |                     |                               'variance_online': {'count': 36864,                          |
# |                       |               |                     |                     |                                                   'mean': -0.0002514455991331488,          |
# |                       |               |                     |                     |                                                   'variance': 0.00351832527667284},        |
# |                       |               |                     |                     |                               'variance_precise': {'count': 36864,                         |
# |                       |               |                     |                     |                                                    'mean': -0.0002514455991331488,         |
# |                       |               |                     |                     |                                                    'variance': 0.0035183250438421965}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | layer1_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {'range_min_max': {'count': 64,                                 |
# |                       |               |                     |                     |                                               'max': 0.0,                                  |
# |                       |               |                     |                     |                                               'min': 0.0,                                  |
# |                       |               |                     |                     |                                               'range': 0.0},                               |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 64,                                 |
# |                       |               |                     |                     |                                               'max': 0.0,                                  |
# |                       |               |                     |                     |                                               'min': 0.0,                                  |
# |                       |               |                     |                     |                                               'range': 0.0},                               |
# |                       |               |                     |                     |                             'range_quantile': {'count': 64,                                |
# |                       |               |                     |                     |                                                'max': 0.0,                                 |
# |                       |               |                     |                     |                                                'min': 0.0,                                 |
# |                       |               |                     |                     |                                                'range': 0.0},                              |
# |                       |               |                     |                     |                             'variance_online': {'count': 64,                               |
# |                       |               |                     |                     |                                                 'mean': 0.0,                               |
# |                       |               |                     |                     |                                                 'variance': 0.0},                          |
# |                       |               |                     |                     |                             'variance_precise': {'count': 64,                              |
# |                       |               |                     |                     |                                                  'mean': 0.0,                              |
# |                       |               |                     |                     |                                                  'variance': 0.0}}},                       |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 131072,                        |
# |                       |               |                     |                     |                                                    'max': 9.736860275268555,               |
# |                       |               |                     |                     |                                                    'min': -8.820615768432617,              |
# |                       |               |                     |                     |                                                    'range': 18.557476043701172},           |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 131072,                        |
# |                       |               |                     |                     |                                                    'max': 4.903622627258301,               |
# |                       |               |                     |                     |                                                    'min': -5.0552215576171875,             |
# |                       |               |                     |                     |                                                    'range': 9.958844184875488},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 131072,                       |
# |                       |               |                     |                     |                                                     'max': 3.130037307739258,              |
# |                       |               |                     |                     |                                                     'min': -3.392446994781494,             |
# |                       |               |                     |                     |                                                     'range': 6.522484302520752},           |
# |                       |               |                     |                     |                                  'variance_online': {'count': 131072,                      |
# |                       |               |                     |                     |                                                      'mean': -0.0757993683218956,          |
# |                       |               |                     |                     |                                                      'variance': 2.7556111812591553},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 131072,                     |
# |                       |               |                     |                     |                                                       'mean': -0.075799360871315,          |
# |                       |               |                     |                     |                                                       'variance': 2.754960298538208}}},    |
# |                       |               |                     |                     |           'running_mean': {'stat': {'range_min_max': {'count': 64,                         |
# |                       |               |                     |                     |                                                       'max': 0.0,                          |
# |                       |               |                     |                     |                                                       'min': 0.0,                          |
# |                       |               |                     |                     |                                                       'range': 0.0},                       |
# |                       |               |                     |                     |                                     'range_n_sigma': {'count': 64,                         |
# |                       |               |                     |                     |                                                       'max': 0.0,                          |
# |                       |               |                     |                     |                                                       'min': 0.0,                          |
# |                       |               |                     |                     |                                                       'range': 0.0},                       |
# |                       |               |                     |                     |                                     'range_quantile': {'count': 64,                        |
# ...
# |                       |               |                     |                     |                                                      'variance': 1.6494851112365723},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                      |
# |                       |               |                     |                     |                                                       'mean': 0.5815503597259521,          |
# |                       |               |                     |                     |                                                       'variance': 1.6463677883148193}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | avgpool               | call_module   | module_related_func | adaptive_avg_pool2d | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 16384,                         |
# |                       |               |                     |                     |                                                    'max': 4.901577949523926,               |
# |                       |               |                     |                     |                                                    'min': 0.0,                             |
# |                       |               |                     |                     |                                                    'range': 4.901577949523926},            |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 16384,                         |
# |                       |               |                     |                     |                                                    'max': 3.773155689239502,               |
# |                       |               |                     |                     |                                                    'min': -2.057161808013916,              |
# |                       |               |                     |                     |                                                    'range': 5.830317497253418},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 16384,                        |
# |                       |               |                     |                     |                                                     'max': 3.203117847442627,              |
# |                       |               |                     |                     |                                                     'min': 0.0,                            |
# |                       |               |                     |                     |                                                     'range': 3.203117847442627},           |
# |                       |               |                     |                     |                                  'variance_online': {'count': 16384,                       |
# |                       |               |                     |                     |                                                      'mean': 0.8579968214035034,           |
# |                       |               |                     |                     |                                                      'variance': 0.9460256695747375},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                      |
# |                       |               |                     |                     |                                                       'mean': 0.8579968214035034,          |
# |                       |               |                     |                     |                                                       'variance': 0.9442389607429504}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | flatten               | call_function | implicit_func       | flatten             | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}             |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | fc                    | call_module   | module_related_func | linear              | {'args': {'bias': {'stat': {'range_min_max': {'count': 10,                                 |
# |                       |               |                     |                     |                                               'max': 0.044095586985349655,                 |
# |                       |               |                     |                     |                                               'min': -0.0392267070710659,                  |
# |                       |               |                     |                     |                                               'range': 0.08332229405641556},               |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 10,                                 |
# |                       |               |                     |                     |                                               'max': 0.08418773114681244,                  |
# |                       |               |                     |                     |                                               'min': -0.07796786725521088,                 |
# |                       |               |                     |                     |                                               'range': 0.16215559840202332},               |
# |                       |               |                     |                     |                             'range_quantile': {'count': 10,                                |
# |                       |               |                     |                     |                                                'max': 0.04072403535246849,                 |
# |                       |               |                     |                     |                                                'min': -0.03658969700336456,                |
# |                       |               |                     |                     |                                                'range': 0.07731373608112335},              |
# |                       |               |                     |                     |                             'variance_online': {'count': 10,                               |
# |                       |               |                     |                     |                                                 'mean': 0.003109933575615287,              |
# |                       |               |                     |                     |                                                 'variance': 0.0007304010214284062},        |
# |                       |               |                     |                     |                             'variance_precise': {'count': 10,                              |
# |                       |               |                     |                     |                                                  'mean': 0.003109933575615287,             |
# |                       |               |                     |                     |                                                  'variance': 0.0007304010214284062}}},     |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 16384,                         |
# |                       |               |                     |                     |                                                    'max': 4.901577949523926,               |
# |                       |               |                     |                     |                                                    'min': 0.0,                             |
# |                       |               |                     |                     |                                                    'range': 4.901577949523926},            |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 16384,                         |
# |                       |               |                     |                     |                                                    'max': 3.773155689239502,               |
# |                       |               |                     |                     |                                                    'min': -2.057161808013916,              |
# |                       |               |                     |                     |                                                    'range': 5.830317497253418},            |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 16384,                        |
# |                       |               |                     |                     |                                                     'max': 3.203117847442627,              |
# |                       |               |                     |                     |                                                     'min': 0.0,                            |
# |                       |               |                     |                     |                                                     'range': 3.203117847442627},           |
# |                       |               |                     |                     |                                  'variance_online': {'count': 16384,                       |
# |                       |               |                     |                     |                                                      'mean': 0.8579968214035034,           |
# |                       |               |                     |                     |                                                      'variance': 0.9460256695747375},      |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                      |
# |                       |               |                     |                     |                                                       'mean': 0.8579968214035034,          |
# |                       |               |                     |                     |                                                       'variance': 0.9442389607429504}}},   |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 5120,                             |
# |                       |               |                     |                     |                                                 'max': 0.044162530452013016,               |
# |                       |               |                     |                     |                                                 'min': -0.04418979957699776,               |
# |                       |               |                     |                     |                                                 'range': 0.08835233002901077},             |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 5120,                             |
# |                       |               |                     |                     |                                                 'max': 0.07724110037088394,                |
# |                       |               |                     |                     |                                                 'min': -0.07689683884382248,               |
# |                       |               |                     |                     |                                                 'range': 0.15413793921470642},             |
# |                       |               |                     |                     |                               'range_quantile': {'count': 5120,                            |
# |                       |               |                     |                     |                                                  'max': 0.04168073087930679,               |
# |                       |               |                     |                     |                                                  'min': -0.041527505964040756,             |
# |                       |               |                     |                     |                                                  'range': 0.08320823311805725},            |
# |                       |               |                     |                     |                               'variance_online': {'count': 5120,                           |
# |                       |               |                     |                     |                                                   'mean': 0.00017213124374393374,          |
# |                       |               |                     |                     |                                                   'variance': 0.0006599584012292325},      |
# |                       |               |                     |                     |                               'variance_precise': {'count': 5120,                          |
# |                       |               |                     |                     |                                                    'mean': 0.00017213124374393374,         |
# |                       |               |                     |                     |                                                    'variance': 0.0006599584012292325}}}},  |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                  |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# | output                | output        | output              | output              | {'args': {'data_in_0': {'stat': {}}}}                                                      |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------------+
# [2023-07-27 22:14:40][chop.passes.analysis.report.report_node][INFO] Node meta param table is saved to /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27/software/transformed_ckpts/report
# [2023-07-27 22:14:40][chop.passes.transforms.interface.save_and_load][INFO] Saved mase graph to /data/zz7522/Projects/mase-tools/mase_output/resnet18_classification_cifar10_2023-07-27/software/transformed_ckpts
# [2023-07-27 22:14:40][chop][INFO] Transformation is completed
