# %% [markdown]
# # Use Existing Statistical Profiler without CLI
#
# This tutorial describes how to use the statistical profiler to collect
# statistics of parameters and activations of a model.

# %% [markdown]
# ## Import related packages and machop

# %%
import sys
import logging
import os
from pathlib import Path
from pprint import pprint as pp

# %%
machop_path = Path(".").resolve().parent.parent.parent.parent.parent /"machop"
assert machop_path.exists(), "Failed to find machop at: {}".format(machop_path)
sys.path.append(str(machop_path))

# %%
from chop.models import get_resnet18
from chop.passes.graph.mase_graph import MaseGraph
from chop.tools.get_input import InputGenerator
from chop.passes import (
    add_common_metadata_analysis_pass,
    add_mase_ops_analysis_pass,
    init_metadata_analysis_pass,
    add_software_metadata_analysis_pass,
)
from chop.passes.analysis import (
    report_node_meta_param_analysis_pass,
    profile_statistics_analysis_pass,
)
from chop.passes.transforms.interface import save_node_meta_param_transform_pass
from chop.tools.logger import getLogger
from chop.dataset import MyDataModule, get_dataset_info

logger = getLogger("chop")
logger.setLevel(logging.INFO)

# %% [markdown]
# ## Set up dataset and model
#
# Here we use a trained ResNet18 model and Cifar10 dataset as example. Though the model checkpoint was trained on ImageNet, we just use it to show how to use the statistical profiler.

# %%
batch_size = 8
model_name = "resnet18"
dataset_name = "cifar10"

datamodule = MyDataModule(
    model_name=model_name,
    batch_size=batch_size,
    dataset_name=dataset_name,
    workers=os.cpu_count(),
    tokenizer=None,
    max_token_len=None,
)
datamodule.prepare_data()
datamodule.setup()

input_generator = InputGenerator(
    datamodule=datamodule,
    task="cls",
    is_nlp_model=False,
    which_dataloader="train",
)

info = get_dataset_info(dataset_name)
model = get_resnet18(info, pretrained=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# [2023-07-27 20:35:14][chop.models.vision.resnet.resnet][WARNING] The num_classes(=10) != 1000. The last layer (FC classifier) is random initialized
# [2023-07-27 20:35:14][chop.models.vision.resnet.resnet][INFO] Pretrained weights loaded into Resnet

# %% [markdown]
# ## Generate MaseGraph
# Statistical profiler is an analysis pass working on a MaseGraph, so we
# need to generate the MaseGraph of ResNet18 first.

# %%
# Test if the sample from dataloader can be passed to the model
dummy_in = {"x": next(iter(datamodule.train_dataloader()))[0]}
_ = model(**dummy_in)

# generate the mase graph and initialize node metadata
mg = MaseGraph(model=model)
mg = init_metadata_analysis_pass(mg, None)
mg = add_mase_ops_analysis_pass(mg, None)
mg = add_common_metadata_analysis_pass(mg, dummy_in)
mg = add_software_metadata_analysis_pass(mg, None)

# %% [markdown]
# ## Statistic Class

# %% [markdown]
# Here is a list of all the supported statistics. Refer to the `__init__` of statistic classes in `chop.passes.analysis.statistical_profiler.stat` to check the args each stat class takes.

# %%
from chop.passes.analysis.statistical_profiler.stat import STAT_NAME_TO_CLS
pp(list(STAT_NAME_TO_CLS.keys()))
# Out:
# ['record',
#  'variance_online',
#  'variance_precise',
#  'range_n_sigma',
#  'range_min_max',
#  'range_quantile']

# %% [markdown]
# ## Profile statistics
#
# The pass `profile_statistics_analysis_pass` collects statistics of parameters and activations, and save them to node's metadata.
#
# ### Example: the range of weights & input activations of a `Conv2d` node
#
# Say we want to collect the tensor-wise min-max range of the 1st `torch.nn.Conv2d` nodes' weights & bias, and the channel-wise 97% quantile min-max of the 1st `torch.nn.Conv2d` nodes' input activations. We can do the following:
#
# > **Note**
# > - Tensor-wise min-max of weights: `Conv2d` has a weight tensor of shape `(out_channels, in_channels, kernel_size, kernel_size)`, so we need to reduce all dimensions of the weight tensor.
# > - Channel-wise 97% quantile min-max of activations: `Conv2d` has an activation tensor of shape `(batch_size, in_channels, height, width)`, so we need to reduce the `0`-th, `2`-nd, and `3`-rd dimensions of the activation tensor. 97% quantile min-max means we sort the input activation tensors ascendingly, and take the min at 3% of the sorted tensor, and the max at 97% of the sorted tensor.

# %%
pass_args = {
    "by": "name", # collect statistics by node name
    "target_weight_nodes": ["conv1"], # the 1st conv2d node name is "conv1"
    "target_activation_nodes": ["conv1"],
    "weight_statistics": {
        # collect the min-max range of the weight tensor
        "range_min_max": {
            "dims": "all", # reduce all dimensions
            "abs": False, # do not take the absolute value before min max reduction
        }
    },
    "activation_statistics": {
        "range_quantile": {
            "dims": [0, 2, 3], # reduced dim = 0, 2, 3. The min-max is a 1D tensor of shape (C_in,)
            "abs": False,
            "quantile": 0.97, # take the 97% quantile
        }
    },
    "input_generator": input_generator, # the input generator for feeding data to the model
    "num_samples": 32, # feed 32 samples to the model
}

# %% [markdown]
# We can use the `report_node_meta_param_analysis_pass` to inspect the collected statistics.
#
# Since the input activation of the 1st `Conv2d` node has shape `(1, 3, 32, 32)`, we can see the quantile-based range has 3 elements, corresponding to the 3 channels.

# %%
mg = profile_statistics_analysis_pass(mg, pass_args)
mg = report_node_meta_param_analysis_pass(mg, {"which": ("software",)})
# Out:
# Profiling weight statistics: 100%|██████████| 71/71 [00:00<00:00, 11938.09it/s]
# Profiling act statistics: 100%|██████████| 4/4 [00:00<00:00, 37.55it/s]
# [2023-07-27 20:35:15][chop.passes.analysis.report.report_node][INFO] Inspecting graph [add_common_meta_param_analysis_pass]
# [2023-07-27 20:35:15][chop.passes.analysis.report.report_node][INFO]
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | Node name             | Fx Node op    | Mase type           | Mase op             | Software Param                                                                       |
# +=======================+===============+=====================+=====================+======================================================================================+
# | x                     | placeholder   | placeholder         | placeholder         | {'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | conv1                 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_quantile': {'count': 32768,                  |
# |                       |               |                     |                     |                                                     'max': [1.8378726243972778,      |
# |                       |               |                     |                     |                                                             2.0259103775024414,      |
# |                       |               |                     |                     |                                                             2.273987293243408],      |
# |                       |               |                     |                     |                                                     'min': [-2.1179039478302,        |
# |                       |               |                     |                     |                                                             -2.0357141494750977,     |
# |                       |               |                     |                     |                                                             -1.804444432258606],     |
# |                       |               |                     |                     |                                                     'range': [3.9557766914367676,    |
# |                       |               |                     |                     |                                                               4.061624526977539,     |
# |                       |               |                     |                     |                                                               4.078431606292725]}}}, |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 9408,                       |
# |                       |               |                     |                     |                                                 'max': 1.0164732933044434,           |
# |                       |               |                     |                     |                                                 'min': -0.8433799147605896,          |
# |                       |               |                     |                     |                                                 'range': 1.8598532676696777}}}},     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | bn1                   | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | relu                  | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | maxpool               | call_module   | module_related_func | max_pool2d          | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add                   | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_1                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer1_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_2                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_3                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer2_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_4                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_5                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer3_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_downsample_0 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_downsample_1 | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_6                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_0_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_relu         | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_conv2        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {}}, 'weight': {'stat': {}}},                        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_bn2          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'running_mean': {'stat': {}},                                              |
# |                       |               |                     |                     |           'running_var': {'stat': {}},                                               |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | add_7                 | call_function | builtin_func        | add                 | {'args': {'data_in_0': {'stat': {}}, 'data_in_1': {'stat': {}}},                     |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | layer4_1_relu_1       | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | avgpool               | call_module   | module_related_func | adaptive_avg_pool2d | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | flatten               | call_function | implicit_func       | flatten             | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}       |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | fc                    | call_module   | module_related_func | linear              | {'args': {'bias': {'stat': {}},                                                      |
# |                       |               |                     |                     |           'data_in_0': {'stat': {}},                                                 |
# |                       |               |                     |                     |           'weight': {'stat': {}}},                                                   |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                            |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+
# | output                | output        | output              | output              | {'args': {'data_in_0': {'stat': {}}}}                                                |
# +-----------------------+---------------+---------------------+---------------------+--------------------------------------------------------------------------------------+

# %% [markdown]
# ### A More Complex Example
#
# Here is an example of collecting various statistics of a ResNet18 model by node type.

# %%
pass_args = {
    "by": "type",
    "target_weight_nodes": [
        "linear",
        "conv2d",
        "batch_norm2d",
        "adaptive_avg_pool2d",
        "relu",
    ],
    "target_activation_nodes": [
        "linear",
        "conv2d",
        "batch_norm2d",
        "adaptive_avg_pool2d",
        "relu",
    ],
    "weight_statistics": {
        # "record": {"device": "cuda"},
        "variance_online": {"device": "cuda", "dims": "all"},
        "variance_precise": {"device": "cuda", "dims": "all"},
        "range_n_sigma": {
            "device": "cuda",
            "dims": "all",
            "abs": False,
            "var_mode": "precise",
            "num_sigma": 3,
        },
        "range_min_max": {"device": "cuda", "dims": "all", "abs": False},
        "range_quantile": {
            "device": "cuda",
            "dims": "all",
            "abs": False,
            "quantile": 0.97,
        },
    },
    "activation_statistics": {
        # "record": {"device": "cuda"},
        "variance_online": {"device": "cuda", "dims": "all"},
        "variance_precise": {"device": "cuda", "dims": "all"},
        "range_n_sigma": {
            "device": "cuda",
            "dims": "all",
            "abs": False,
            "var_mode": "precise",
            "num_sigma": 3,
        },
        "range_min_max": {"device": "cuda", "dims": "all", "abs": False},
        "range_quantile": {
            "device": "cuda",
            "dims": "all",
            "abs": False,
            "quantile": 0.97,
        },
    },
    "input_generator": input_generator,
    "num_samples": 32,
}

# %% [markdown]
# Clear the meta data of the MaseGraph first.
#
# Then we can collect the statistics of the model.

# %%
# clear the metadata
mg = init_metadata_analysis_pass(mg, None)
mg = add_mase_ops_analysis_pass(mg, None)
mg = add_common_metadata_analysis_pass(mg, dummy_in)
mg = add_software_metadata_analysis_pass(mg, None)

# %% [markdown]
# We can save the collected statistics to a toml file with `save_node_param_transform_pass`.

# %%
mg = profile_statistics_analysis_pass(mg, pass_args)
mg = report_node_meta_param_analysis_pass(mg, {"which": ("software",)})
mg = save_node_meta_param_transform_pass(
    mg,
    "./node_software_meta_param_no_CLI.toml",
)
# Out:
# Profiling weight statistics:   0%|          | 0/71 [00:00<?, ?it/s]/home/zz7522/anaconda3/envs/mase-sw/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Profiling weight statistics: 100%|██████████| 71/71 [00:02<00:00, 34.78it/s]
# Profiling act statistics: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# [2023-07-27 20:35:19][chop.passes.analysis.report.report_node][INFO] Inspecting graph [add_common_meta_param_analysis_pass]
# [2023-07-27 20:35:19][chop.passes.analysis.report.report_node][INFO]
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | Node name             | Fx Node op    | Mase type           | Mase op             | Software Param                                                                                  |
# +=======================+===============+=====================+=====================+=================================================================================================+
# | x                     | placeholder   | placeholder         | placeholder         | {'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | conv1                 | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 98304,                              |
# |                       |               |                     |                     |                                                    'max': 3.0866312980651855,                   |
# |                       |               |                     |                     |                                                    'min': -3.5057663917541504,                  |
# |                       |               |                     |                     |                                                    'range': 6.592397689819336},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 98304,                              |
# |                       |               |                     |                     |                                                    'max': 3.86967396736145,                     |
# |                       |               |                     |                     |                                                    'min': -3.760906934738159,                   |
# |                       |               |                     |                     |                                                    'range': 7.630580902099609},                 |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 98304,                             |
# |                       |               |                     |                     |                                                     'max': 2.4285714626312256,                  |
# |                       |               |                     |                     |                                                     'min': -2.1179039478302,                    |
# |                       |               |                     |                     |                                                     'range': 4.546475410461426},                |
# |                       |               |                     |                     |                                  'variance_online': {'count': 98304,                            |
# |                       |               |                     |                     |                                                      'mean': 0.05438341200351715,               |
# |                       |               |                     |                     |                                                      'variance': 1.6177089214324951},           |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 98304,                           |
# |                       |               |                     |                     |                                                       'mean': 0.05438341200351715,              |
# |                       |               |                     |                     |                                                       'variance': 1.6173824071884155}}},        |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 9408,                                  |
# |                       |               |                     |                     |                                                 'max': 1.0164732933044434,                      |
# |                       |               |                     |                     |                                                 'min': -0.8433799147605896,                     |
# |                       |               |                     |                     |                                                 'range': 1.8598532676696777},                   |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 9408,                                  |
# |                       |               |                     |                     |                                                 'max': 0.3891241252422333,                      |
# |                       |               |                     |                     |                                                 'min': -0.38906529545783997,                    |
# |                       |               |                     |                     |                                                 'range': 0.7781894207000732},                   |
# |                       |               |                     |                     |                               'range_quantile': {'count': 9408,                                 |
# |                       |               |                     |                     |                                                  'max': 0.263347864151001,                      |
# |                       |               |                     |                     |                                                  'min': -0.266735702753067,                     |
# |                       |               |                     |                     |                                                  'range': 0.5300835371017456},                  |
# |                       |               |                     |                     |                               'variance_online': {'count': 9408,                                |
# |                       |               |                     |                     |                                                   'mean': 2.941970706160646e-05,                |
# |                       |               |                     |                     |                                                   'variance': 0.01682163216173649},             |
# |                       |               |                     |                     |                               'variance_precise': {'count': 9408,                               |
# |                       |               |                     |                     |                                                    'mean': 2.941970706160646e-05,               |
# |                       |               |                     |                     |                                                    'variance': 0.01682163216173649}}}},         |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | bn1                   | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {'range_min_max': {'count': 64,                                      |
# |                       |               |                     |                     |                                               'max': 0.6759758591651917,                        |
# |                       |               |                     |                     |                                               'min': -0.66438889503479,                         |
# |                       |               |                     |                     |                                               'range': 1.340364694595337},                      |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 64,                                      |
# |                       |               |                     |                     |                                               'max': 1.0779625177383423,                        |
# |                       |               |                     |                     |                                               'min': -0.7157220840454102,                       |
# |                       |               |                     |                     |                                               'range': 1.7936846017837524},                     |
# |                       |               |                     |                     |                             'range_quantile': {'count': 64,                                     |
# |                       |               |                     |                     |                                                'max': 0.5877653360366821,                       |
# |                       |               |                     |                     |                                                'min': -0.5407459735870361,                      |
# |                       |               |                     |                     |                                                'range': 1.1285113096237183},                    |
# |                       |               |                     |                     |                             'variance_online': {'count': 64,                                    |
# |                       |               |                     |                     |                                                 'mean': 0.18112018704414368,                    |
# |                       |               |                     |                     |                                                 'variance': 0.08936957269906998},               |
# |                       |               |                     |                     |                             'variance_precise': {'count': 64,                                   |
# |                       |               |                     |                     |                                                  'mean': 0.18112018704414368,                   |
# |                       |               |                     |                     |                                                  'variance': 0.08936957269906998}}},            |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 524288,                             |
# |                       |               |                     |                     |                                                    'max': 31.84914779663086,                    |
# |                       |               |                     |                     |                                                    'min': -35.52656555175781,                   |
# |                       |               |                     |                     |                                                    'range': 67.37571716308594},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 524288,                             |
# |                       |               |                     |                     |                                                    'max': 7.384454727172852,                    |
# |                       |               |                     |                     |                                                    'min': -7.3955793380737305,                  |
# |                       |               |                     |                     |                                                    'range': 14.780034065246582},                |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 524288,                            |
# |                       |               |                     |                     |                                                     'max': 4.462757110595703,                   |
# |                       |               |                     |                     |                                                     'min': -4.5221848487854,                    |
# |                       |               |                     |                     |                                                     'range': 8.984941482543945},                |
# |                       |               |                     |                     |                                  'variance_online': {'count': 524288,                           |
# |                       |               |                     |                     |                                                      'mean': -0.005562382750213146,             |
# |                       |               |                     |                     |                                                      'variance': 6.068397045135498},            |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 524288,                          |
# |                       |               |                     |                     |                                                       'mean': -0.0055623846128582954,           |
# |                       |               |                     |                     |                                                       'variance': 6.0680389404296875}}},        |
# |                       |               |                     |                     |           'running_mean': {'stat': {'range_min_max': {'count': 64,                              |
# |                       |               |                     |                     |                                                       'max': 0.15734493732452393,               |
# |                       |               |                     |                     |                                                       'min': -0.20609907805919647,              |
# |                       |               |                     |                     |                                                       'range': 0.3634440302848816},             |
# |                       |               |                     |                     |                                     'range_n_sigma': {'count': 64,                              |
# |                       |               |                     |                     |                                                       'max': 0.25999900698661804,               |
# |                       |               |                     |                     |                                                       'min': -0.26403090357780457,              |
# |                       |               |                     |                     |                                                       'range': 0.5240299105644226},             |
# |                       |               |                     |                     |                                     'range_quantile': {'count': 64,                             |
# |                       |               |                     |                     |                                                        'max': 0.14290422201156616,              |
# |                       |               |                     |                     |                                                        'min': -0.15574459731578827,             |
# |                       |               |                     |                     |                                                        'range': 0.2986488342285156},            |
# |                       |               |                     |                     |                                     'variance_online': {'count': 64,                            |
# |                       |               |                     |                     |                                                         'mean': -0.002015952719375491,          |
# |                       |               |                     |                     |                                                         'variance': 0.007627981714904308},      |
# |                       |               |                     |                     |                                     'variance_precise': {'count': 64,                           |
# |                       |               |                     |                     |                                                          'mean': -0.002015952719375491,         |
# |                       |               |                     |                     |                                                          'variance': 0.007627981714904308}}},   |
# |                       |               |                     |                     |           'running_var': {'stat': {'range_min_max': {'count': 64,                               |
# |                       |               |                     |                     |                                                      'max': 25.360809326171875,                 |
# |                       |               |                     |                     |                                                      'min': 8.898812947372853e-14,              |
# |                       |               |                     |                     |                                                      'range': 25.360809326171875},              |
# |                       |               |                     |                     |                                    'range_n_sigma': {'count': 64,                               |
# |                       |               |                     |                     |                                                      'max': 17.608036041259766,                 |
# |                       |               |                     |                     |                                                      'min': -9.10047435760498,                  |
# |                       |               |                     |                     |                                                      'range': 26.708511352539062},              |
# |                       |               |                     |                     |                                    'range_quantile': {'count': 64,                              |
# |                       |               |                     |                     |                                                       'max': 13.077670097351074,                |
# |                       |               |                     |                     |                                                       'min': 2.4785924181147667e-13,            |
# |                       |               |                     |                     |                                                       'range': 13.077670097351074},             |
# |                       |               |                     |                     |                                    'variance_online': {'count': 64,                             |
# |                       |               |                     |                     |                                                        'mean': 4.253781318664551,               |
# |                       |               |                     |                     |                                                        'variance': 19.815126419067383},         |
# |                       |               |                     |                     |                                    'variance_precise': {'count': 64,                            |
# |                       |               |                     |                     |                                                         'mean': 4.253781318664551,              |
# |                       |               |                     |                     |                                                         'variance': 19.815126419067383}}},      |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 64,                                    |
# |                       |               |                     |                     |                                                 'max': 0.5258306860923767,                      |
# |                       |               |                     |                     |                                                 'min': -5.1095959463509644e-08,                 |
# |                       |               |                     |                     |                                                 'range': 0.5258307456970215},                   |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 64,                                    |
# |                       |               |                     |                     |                                                 'max': 0.6269875764846802,                      |
# |                       |               |                     |                     |                                                 'min': -0.11183306574821472,                    |
# |                       |               |                     |                     |                                                 'range': 0.7388206720352173},                   |
# |                       |               |                     |                     |                               'range_quantile': {'count': 64,                                   |
# |                       |               |                     |                     |                                                  'max': 0.4871551990509033,                     |
# |                       |               |                     |                     |                                                  'min': 1.349715539333829e-08,                  |
# |                       |               |                     |                     |                                                  'range': 0.4871551990509033},                  |
# |                       |               |                     |                     |                               'variance_online': {'count': 64,                                  |
# |                       |               |                     |                     |                                                   'mean': 0.25757724046707153,                  |
# |                       |               |                     |                     |                                                   'variance': 0.015162662602961063},            |
# |                       |               |                     |                     |                               'variance_precise': {'count': 64,                                 |
# |                       |               |                     |                     |                                                    'mean': 0.25757724046707153,                 |
# |                       |               |                     |                     |                                                    'variance': 0.015162662602961063}}}},        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | relu                  | call_module   | module_related_func | relu                | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 524288,                             |
# |                       |               |                     |                     |                                                    'max': 3.244997262954712,                    |
# |                       |               |                     |                     |                                                    'min': -2.3160085678100586,                  |
# |                       |               |                     |                     |                                                    'range': 5.561005592346191},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 524288,                             |
# |                       |               |                     |                     |                                                    'max': 1.4153022766113281,                   |
# |                       |               |                     |                     |                                                    'min': -1.0530619621276855,                  |
# |                       |               |                     |                     |                                                    'range': 2.4683642387390137},                |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 524288,                            |
# |                       |               |                     |                     |                                                     'max': 0.8958170413970947,                  |
# |                       |               |                     |                     |                                                     'min': -0.8082477450370789,                 |
# |                       |               |                     |                     |                                                     'range': 1.7040648460388184},               |
# |                       |               |                     |                     |                                  'variance_online': {'count': 524288,                           |
# |                       |               |                     |                     |                                                      'mean': 0.18112018704414368,               |
# |                       |               |                     |                     |                                                      'variance': 0.16925504803657532},          |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 524288,                          |
# |                       |               |                     |                     |                                                       'mean': 0.18112018704414368,              |
# |                       |               |                     |                     |                                                       'variance': 0.16924504935741425}}}},      |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | maxpool               | call_module   | module_related_func | max_pool2d          | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}                  |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | layer1_0_conv1        | call_module   | module_related_func | conv2d              | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 131072,                             |
# |                       |               |                     |                     |                                                    'max': 3.244997262954712,                    |
# |                       |               |                     |                     |                                                    'min': 0.0,                                  |
# |                       |               |                     |                     |                                                    'range': 3.244997262954712},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 131072,                             |
# |                       |               |                     |                     |                                                    'max': 1.4426121711730957,                   |
# |                       |               |                     |                     |                                                    'min': -0.6168749332427979,                  |
# |                       |               |                     |                     |                                                    'range': 2.0594871044158936},                |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 131072,                            |
# |                       |               |                     |                     |                                                     'max': 1.1560721397399902,                  |
# |                       |               |                     |                     |                                                     'min': 0.0,                                 |
# |                       |               |                     |                     |                                                     'range': 1.1560721397399902},               |
# |                       |               |                     |                     |                                  'variance_online': {'count': 131072,                           |
# |                       |               |                     |                     |                                                      'mean': 0.4128686189651489,                |
# |                       |               |                     |                     |                                                      'variance': 0.1178460344672203},           |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 131072,                          |
# |                       |               |                     |                     |                                                       'mean': 0.41286858916282654,              |
# |                       |               |                     |                     |                                                       'variance': 0.11781907826662064}}},       |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 36864,                                 |
# |                       |               |                     |                     |                                                 'max': 0.6196322441101074,                      |
# |                       |               |                     |                     |                                                 'min': -0.7993080019950867,                     |
# |                       |               |                     |                     |                                                 'range': 1.4189403057098389},                   |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 36864,                                 |
# |                       |               |                     |                     |                                                 'max': 0.15710623562335968,                     |
# |                       |               |                     |                     |                                                 'min': -0.16328032314777374,                    |
# |                       |               |                     |                     |                                                 'range': 0.3203865587711334},                   |
# |                       |               |                     |                     |                               'range_quantile': {'count': 36864,                                |
# |                       |               |                     |                     |                                                  'max': 0.08296290785074234,                    |
# |                       |               |                     |                     |                                                  'min': -0.11259426176548004,                   |
# |                       |               |                     |                     |                                                  'range': 0.19555717706680298},                 |
# |                       |               |                     |                     |                               'variance_online': {'count': 36864,                               |
# |                       |               |                     |                     |                                                   'mean': -0.0030870495829731226,               |
# |                       |               |                     |                     |                                                   'variance': 0.0028513208962976933},           |
# |                       |               |                     |                     |                               'variance_precise': {'count': 36864,                              |
# |                       |               |                     |                     |                                                    'mean': -0.0030870495829731226,              |
# |                       |               |                     |                     |                                                    'variance': 0.0028513208962976933}}}},       |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | layer1_0_bn1          | call_module   | module              | batch_norm2d        | {'args': {'bias': {'stat': {'range_min_max': {'count': 64,                                      |
# |                       |               |                     |                     |                                               'max': 0.3294556438922882,                        |
# |                       |               |                     |                     |                                               'min': -0.5315352082252502,                       |
# |                       |               |                     |                     |                                               'range': 0.8609908819198608},                     |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 64,                                      |
# |                       |               |                     |                     |                                               'max': 0.5945376753807068,                        |
# |                       |               |                     |                     |                                               'min': -0.6628108620643616,                       |
# |                       |               |                     |                     |                                               'range': 1.2573485374450684},                     |
# |                       |               |                     |                     |                             'range_quantile': {'count': 64,                                     |
# |                       |               |                     |                     |                                                'max': 0.3126133382320404,                       |
# |                       |               |                     |                     |                                                'min': -0.48573628067970276,                     |
# |                       |               |                     |                     |                                                'range': 0.7983496189117432},                    |
# |                       |               |                     |                     |                             'variance_online': {'count': 64,                                    |
# |                       |               |                     |                     |                                                 'mean': -0.0341365709900856,                    |
# |                       |               |                     |                     |                                                 'variance': 0.04391459375619888},               |
# |                       |               |                     |                     |                             'variance_precise': {'count': 64,                                   |
# |                       |               |                     |                     |                                                  'mean': -0.0341365709900856,                   |
# |                       |               |                     |                     |                                                  'variance': 0.04391459375619888}}},            |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 131072,                             |
# |                       |               |                     |                     |                                                    'max': 4.905399799346924,                    |
# |                       |               |                     |                     |                                                    'min': -9.670665740966797,                   |
# |                       |               |                     |                     |                                                    'range': 14.576065063476562},                |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 131072,                             |
# |                       |               |                     |                     |                                                    'max': 2.693850517272949,                    |
# |                       |               |                     |                     |                                                    'min': -4.712630271911621,                   |
# |                       |               |                     |                     |                                                    'range': 7.40648078918457},                  |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 131072,                            |
# |                       |               |                     |                     |                                                     'max': 1.3111166954040527,                  |
# |                       |               |                     |                     |                                                     'min': -3.4686853885650635,                 |
# |                       |               |                     |                     |                                                     'range': 4.779802322387695},                |
# |                       |               |                     |                     |                                  'variance_online': {'count': 131072,                           |
# |                       |               |                     |                     |                                                      'mean': -1.009390115737915,                |
# |                       |               |                     |                     |                                                      'variance': 1.524131417274475},            |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 131072,                          |
# |                       |               |                     |                     |                                                       'mean': -1.009389877319336,               |
# |                       |               |                     |                     |                                                       'variance': 1.523776650428772}}},         |
# |                       |               |                     |                     |           'running_mean': {'stat': {'range_min_max': {'count': 64,                              |
# |                       |               |                     |                     |                                                       'max': 1.4414652585983276,                |
# |                       |               |                     |                     |                                                       'min': -3.0225746631622314,               |
# |                       |               |                     |                     |                                                       'range': 4.4640398025512695},             |
# |                       |               |                     |                     |                                     'range_n_sigma': {'count': 64,                              |
# |                       |               |                     |                     |                                                       'max': 1.8162509202957153,                |
# |                       |               |                     |                     |                                                       'min': -3.7222375869750977,               |
# |                       |               |                     |                     |                                                       'range': 5.538488388061523},              |
# |                       |               |                     |                     |                                     'range_quantile': {'count': 64,                             |
# |                       |               |                     |                     |                                                        'max': 0.6386292576789856,               |
# |                       |               |                     |                     |                                                        'min': -2.580702066421509,               |
# |                       |               |                     |                     |                                                        'range': 3.2193312644958496},            |
# |                       |               |                     |                     |                                     'variance_online': {'count': 64,                            |
# |                       |               |                     |                     |                                                         'mean': -0.9529932737350464,            |
# |                       |               |                     |                     |                                                         'variance': 0.8520793318748474},        |
# |                       |               |                     |                     |                                     'variance_precise': {'count': 64,                           |
# |                       |               |                     |                     |                                                          'mean': -0.9529932737350464,           |
# |                       |               |                     |                     |                                                          'variance': 0.8520793318748474}}},     |
# |                       |               |                     |                     |           'running_var': {'stat': {'range_min_max': {'count': 64,                               |
# |                       |               |                     |                     |                                                      'max': 1.7683501243591309,                 |
# |                       |               |                     |                     |                                                      'min': 0.08022448420524597,                |
# |                       |               |                     |                     |                                                      'range': 1.6881256103515625},              |
# |                       |               |                     |                     |                                    'range_n_sigma': {'count': 64,                               |
# |                       |               |                     |                     |                                                      'max': 1.6825511455535889,                 |
# |                       |               |                     |                     |                                                      'min': -0.5428671836853027,                |
# |                       |               |                     |                     |                                                      'range': 2.2254183292388916},              |
# ...
# |                       |               |                     |                     |                                                      'variance': 3.5236196517944336},           |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                           |
# |                       |               |                     |                     |                                                       'mean': 0.3422833979129791,               |
# |                       |               |                     |                     |                                                       'variance': 3.517659902572632}}}},        |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | avgpool               | call_module   | module_related_func | adaptive_avg_pool2d | {'args': {'data_in_0': {'stat': {'range_min_max': {'count': 16384,                              |
# |                       |               |                     |                     |                                                    'max': 6.609770774841309,                    |
# |                       |               |                     |                     |                                                    'min': 0.0,                                  |
# |                       |               |                     |                     |                                                    'range': 6.609770774841309},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 16384,                              |
# |                       |               |                     |                     |                                                    'max': 4.655235767364502,                    |
# |                       |               |                     |                     |                                                    'min': -2.7785868644714355,                  |
# |                       |               |                     |                     |                                                    'range': 7.4338226318359375},                |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 16384,                             |
# |                       |               |                     |                     |                                                     'max': 4.02449369430542,                    |
# |                       |               |                     |                     |                                                     'min': 0.0,                                 |
# |                       |               |                     |                     |                                                     'range': 4.02449369430542},                 |
# |                       |               |                     |                     |                                  'variance_online': {'count': 16384,                            |
# |                       |               |                     |                     |                                                      'mean': 0.9383243918418884,                |
# |                       |               |                     |                     |                                                      'variance': 1.5377317667007446},           |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                           |
# |                       |               |                     |                     |                                                       'mean': 0.9383244514465332,               |
# |                       |               |                     |                     |                                                       'variance': 1.5350476503372192}}}},       |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | flatten               | call_function | implicit_func       | flatten             | {'args': {'data_in_0': {'stat': {}}}, 'results': {'data_out_0': {'stat': {}}}}                  |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | fc                    | call_module   | module_related_func | linear              | {'args': {'bias': {'stat': {'range_min_max': {'count': 10,                                      |
# |                       |               |                     |                     |                                               'max': 0.04199249669909477,                       |
# |                       |               |                     |                     |                                               'min': -0.04116304963827133,                      |
# |                       |               |                     |                     |                                               'range': 0.0831555426120758},                     |
# |                       |               |                     |                     |                             'range_n_sigma': {'count': 10,                                      |
# |                       |               |                     |                     |                                               'max': 0.08554641902446747,                       |
# |                       |               |                     |                     |                                               'min': -0.08516260981559753,                      |
# |                       |               |                     |                     |                                               'range': 0.170709028840065},                      |
# |                       |               |                     |                     |                             'range_quantile': {'count': 10,                                     |
# |                       |               |                     |                     |                                                'max': 0.040957994759082794,                     |
# |                       |               |                     |                     |                                                'min': -0.03598394989967346,                     |
# |                       |               |                     |                     |                                                'range': 0.07694194465875626},                   |
# |                       |               |                     |                     |                             'variance_online': {'count': 10,                                    |
# |                       |               |                     |                     |                                                 'mean': 0.00019190199964214116,                 |
# |                       |               |                     |                     |                                                 'variance': 0.000809488061349839},              |
# |                       |               |                     |                     |                             'variance_precise': {'count': 10,                                   |
# |                       |               |                     |                     |                                                  'mean': 0.00019190199964214116,                |
# |                       |               |                     |                     |                                                  'variance': 0.000809488061349839}}},           |
# |                       |               |                     |                     |           'data_in_0': {'stat': {'range_min_max': {'count': 16384,                              |
# |                       |               |                     |                     |                                                    'max': 6.609770774841309,                    |
# |                       |               |                     |                     |                                                    'min': 0.0,                                  |
# |                       |               |                     |                     |                                                    'range': 6.609770774841309},                 |
# |                       |               |                     |                     |                                  'range_n_sigma': {'count': 16384,                              |
# |                       |               |                     |                     |                                                    'max': 4.655235767364502,                    |
# |                       |               |                     |                     |                                                    'min': -2.7785868644714355,                  |
# |                       |               |                     |                     |                                                    'range': 7.4338226318359375},                |
# |                       |               |                     |                     |                                  'range_quantile': {'count': 16384,                             |
# |                       |               |                     |                     |                                                     'max': 4.02449369430542,                    |
# |                       |               |                     |                     |                                                     'min': 0.0,                                 |
# |                       |               |                     |                     |                                                     'range': 4.02449369430542},                 |
# |                       |               |                     |                     |                                  'variance_online': {'count': 16384,                            |
# |                       |               |                     |                     |                                                      'mean': 0.9383243918418884,                |
# |                       |               |                     |                     |                                                      'variance': 1.5377317667007446},           |
# |                       |               |                     |                     |                                  'variance_precise': {'count': 16384,                           |
# |                       |               |                     |                     |                                                       'mean': 0.9383244514465332,               |
# |                       |               |                     |                     |                                                       'variance': 1.5350476503372192}}},        |
# |                       |               |                     |                     |           'weight': {'stat': {'range_min_max': {'count': 5120,                                  |
# |                       |               |                     |                     |                                                 'max': 0.04415912181138992,                     |
# |                       |               |                     |                     |                                                 'min': -0.04418814554810524,                    |
# |                       |               |                     |                     |                                                 'range': 0.08834727108478546},                  |
# |                       |               |                     |                     |                               'range_n_sigma': {'count': 5120,                                  |
# |                       |               |                     |                     |                                                 'max': 0.07637908309698105,                     |
# |                       |               |                     |                     |                                                 'min': -0.0775626078248024,                     |
# |                       |               |                     |                     |                                                 'range': 0.15394169092178345},                  |
# |                       |               |                     |                     |                               'range_quantile': {'count': 5120,                                 |
# |                       |               |                     |                     |                                                  'max': 0.04148156940937042,                    |
# |                       |               |                     |                     |                                                  'min': -0.041356708854436874,                  |
# |                       |               |                     |                     |                                                  'range': 0.0828382819890976},                  |
# |                       |               |                     |                     |                               'variance_online': {'count': 5120,                                |
# |                       |               |                     |                     |                                                   'mean': -0.0005917609087191522,               |
# |                       |               |                     |                     |                                                   'variance': 0.0006582789937965572},           |
# |                       |               |                     |                     |                               'variance_precise': {'count': 5120,                               |
# |                       |               |                     |                     |                                                    'mean': -0.0005917609087191522,              |
# |                       |               |                     |                     |                                                    'variance': 0.0006582789937965572}}}},       |
# |                       |               |                     |                     |  'results': {'data_out_0': {'stat': {}}}}                                                       |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
# | output                | output        | output              | output              | {'args': {'data_in_0': {'stat': {}}}}                                                           |
# +-----------------------+---------------+---------------------+---------------------+-------------------------------------------------------------------------------------------------+
